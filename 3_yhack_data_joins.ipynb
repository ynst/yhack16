# %%
import pandas as pd

# %%
headers= ['uid', 'address', 'phone', 'schoolType', 'status', 'isCharter', 'detailYears', 'county', 'gradeSpan', 'totalStudents', 'totalTeachers', 'studentTeacherRatio', 'locale', 'titleOneStatus', 'enrollmentYears', 'enrollByGrade', 'enrollByRace', 'enrollByGender', 'freeLunch', 'reducedLunch']

# %%
df = pd.read_csv('yhack16/bios.csv.tar.gz',compression='gzip', header=None)
df.columns = headers

# %%
# first the first one
df.iloc[0]['uid'] = "010000700091"

# %%
df.uid.describe()
# Out:
# count            88822
# unique           88822
# top       120150003909
# freq                 1
# Name: uid, dtype: object

# %%
df.head()
# Out:
#             uid                                         address  \
# 0  010000700091       5454 Learning Lane\nHoover, AL 35244-4529
# 1  010000500879  901 W Mckinney Ave\nAlbertville, AL 35950-1346
# 2  010000500871    402 E Mccord Ave\nAlbertville, AL 35950-2322
# 3  010000600880        2233 Shoal Creek Rd\nArab, AL 35016-3510
# 4  010000600878         225 Eagle Drive\nDouglas, AL 35964-0300
#
#             phone       schoolType                  status isCharter  \
# 0  (205) 439-2700   Regular school   Currently operational         †
# 1  (256) 878-7698   Regular school   Currently operational         †
# 2  (256) 878-6580   Regular school   Currently operational         †
# 3  (256) 753-2246   Regular school   Currently operational         †
# 4  (256) 593-2810   Regular school   Currently operational         †
#
#                               detailYears            county        gradeSpan  \
# 0  School Details (2013-2014 school year)  Jefferson County  (grades PK - 4)
# ...

# %%
df.head()
# Out:
#                 uid                                         address  \
# 0  ./cache/bios.csv       5454 Learning Lane\nHoover, AL 35244-4529
# 1      010000500879  901 W Mckinney Ave\nAlbertville, AL 35950-1346
# 2      010000500871    402 E Mccord Ave\nAlbertville, AL 35950-2322
# 3      010000600880        2233 Shoal Creek Rd\nArab, AL 35016-3510
# 4      010000600878         225 Eagle Drive\nDouglas, AL 35964-0300
#
#             phone       schoolType                  status isCharter  \
# 0  (205) 439-2700   Regular school   Currently operational         †
# 1  (256) 878-7698   Regular school   Currently operational         †
# 2  (256) 878-6580   Regular school   Currently operational         †
# 3  (256) 753-2246   Regular school   Currently operational         †
# 4  (256) 593-2810   Regular school   Currently operational         †
#
#                               detailYears            county        gradeSpan  \
# ...

# %%
df.describe()
# Out:
#                  uid address           phone       schoolType  \
# count          88822   88822           88822            88822
# unique         88822   84052           82493                5
# top     120150003909      -1  (505) 880-3744   Regular school
# freq               1      33             144            85047
#
#                         status isCharter  \
# count                    88822     88822
# unique                       6         4
# top      Currently operational        No
# freq                     87758     74911
#
#                                    detailYears              county  \
# count                                    88822               88822
# unique                                       2                1944
# top     School Details (2013-2014 school year)  Los Angeles County
# freq                                     88789                1904
#
#               gradeSpan totalStudents totalTeachers studentTeacherRatio  \
# ...

# %%
ids = pd.read_csv('./yhack16/cache/ids_full.csv.gz', compression='gzip')

# %%
ids.head()
# Out:
#    Unnamed: 0    STNAM                        SCHNAM   normal_ids
# 0           0  ALABAMA         Ala Avenue Middle Sch  10000500870
# 1           1  ALABAMA          Albertville High Sch  10000500871
# 2           2  ALABAMA                Evans Elem Sch  10000500879
# 3           3  ALABAMA          Albertville Elem Sch  10000500889
# 4           4  ALABAMA  Kate Duncan Smith DAR Middle  10000600193

# %%
# find the missing names
ids[ids['normal_ids'] == 100002200187 ]
# Out:
#        Unnamed: 0     STNAM                        SCHNAM    normal_ids
# 16133       16133  DELAWARE  Silver Lake Treatment Center  100002200187

# %%
# just 33 schools lack address, appears to be because they actually lack a page
df[df['address'] == "-1"].shape
# Out:
# (33, 20)

# %%
clean = df[df['address'] != "-1"]

# %%
clean.describe()
# Out:
#                  uid                                    address  \
# count          88789                                      88789
# unique         88789                                      84051
# top     120150003909  1820 Xenium Ln N\nPlymouth, MN 55441-8888
# freq               1                                          9
#
#                  phone       schoolType                  status isCharter  \
# count            88789            88789                   88789     88789
# unique           82492                4                       5         3
# top     (505) 880-3744   Regular school   Currently operational        No
# freq               144            85047                   87758     74911
#
#                                    detailYears              county  \
# count                                    88789               88789
# unique                                       1                1943
# top     School Details (2013-2014 school year)  Los Angeles County
# ...

# %%
clean.schoolType.unique()
# Out:
# array([' Regular school', ' Other/alternative school',
#        ' Special education school', ' Vocational school'], dtype=object)

# %%
import re
xen = re.compile('Xenium')

# %%
df['cleaned_Addresses'] = df['address'].apply(lambda x: x.replace("\n", " "))

# %%
df.head()
# Out:
#             uid                                         address  \
# 0  010000700091       5454 Learning Lane\nHoover, AL 35244-4529
# 1  010000500879  901 W Mckinney Ave\nAlbertville, AL 35950-1346
# 2  010000500871    402 E Mccord Ave\nAlbertville, AL 35950-2322
# 3  010000600880        2233 Shoal Creek Rd\nArab, AL 35016-3510
# 4  010000600878         225 Eagle Drive\nDouglas, AL 35964-0300
#
#             phone       schoolType                  status isCharter  \
# 0  (205) 439-2700   Regular school   Currently operational         †
# 1  (256) 878-7698   Regular school   Currently operational         †
# 2  (256) 878-6580   Regular school   Currently operational         †
# 3  (256) 753-2246   Regular school   Currently operational         †
# 4  (256) 593-2810   Regular school   Currently operational         †
#
#                               detailYears            county        gradeSpan  \
# 0  School Details (2013-2014 school year)  Jefferson County  (grades PK - 4)
# ...

# %%
clean[clean['address'].apply(lambda x: True if xen.search(x) else False) ]
# Out:
#                 uid                                    address  \
# 40940  270002503213  1820 Xenium Ln N\nPlymouth, MN 55441-8888
# 40941  270002503226  1820 Xenium Ln N\nPlymouth, MN 55441-8888
# 40942  270002503228  1820 Xenium Ln N\nPlymouth, MN 55441-8888
# 40943  270002503232  1820 Xenium Ln N\nPlymouth, MN 55441-8888
# 40944  270002503229  1820 Xenium Ln N\nPlymouth, MN 55441-8888
# 40945  270002503234  1820 Xenium Ln N\nPlymouth, MN 55441-8888
# 40948  270002503542  1820 Xenium Ln N\nPlymouth, MN 55441-8888
# 40951  270002504327  1820 Xenium Ln N\nPlymouth, MN 55441-8888
# 40954  270002503216  1820 Xenium Ln N\nPlymouth, MN 55441-3791
# 40958  270002503597  1820 Xenium Ln N\nPlymouth, MN 55441-8888
#
#                 phone                 schoolType                  status  \
# 40940  (763) 550-7200   Special education school   Currently operational
# 40941  (763) 550-7200   Special education school   Currently operational
# ...

# %%
clean.columns
# Out:
# Index([u'uid', u'address', u'phone', u'schoolType', u'status', u'isCharter',
#        u'detailYears', u'county', u'gradeSpan', u'totalStudents',
#        u'totalTeachers', u'studentTeacherRatio', u'locale', u'titleOneStatus',
#        u'enrollmentYears', u'enrollByGrade', u'enrollByRace',
#        u'enrollByGender', u'freeLunch', u'reducedLunch'],
#       dtype='object')

# %%
clean.head(2)
# Out:
#             uid                                         address  \
# 0  010000700091       5454 Learning Lane\nHoover, AL 35244-4529
# 1  010000500879  901 W Mckinney Ave\nAlbertville, AL 35950-1346
#
#             phone       schoolType                  status isCharter  \
# 0  (205) 439-2700   Regular school   Currently operational         †
# 1  (256) 878-7698   Regular school   Currently operational         †
#
#                               detailYears            county        gradeSpan  \
# 0  School Details (2013-2014 school year)  Jefferson County  (grades PK - 4)
# 1  School Details (2013-2014 school year)   Marshall County   (grades 5 - 6)
#
#   totalStudents totalTeachers studentTeacherRatio                locale  \
# 0           549         40.00               13.72      City: Small (13)
# 1           679         31.25               21.73    Town: Distant (32)
#
#                                       titleOneStatus  \
# ...

# %%
clean[['uid', 'phone' , 'cleaned_Addresses']].to_csv('uid_phone_addresses')
